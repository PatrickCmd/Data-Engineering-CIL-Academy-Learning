# %% [markdown]
# # Basics of Computer Networking, Networking 101
#
# **Resources**
# - https://www.youtube.com/watch?v=0j6-QFnnwQk
# - https://networkdirection.net/labsandquizzes/quizzes/introduction-to-networking/introduction-to-networking-quiz/
# - [DNS: “Translating Names to IP Addresses.”](https://medium.com/@madhusudanpatnaik/dns-translating-names-to-ip-addresses-ebe7b6d8008c)
# - https://www.youtube.com/watch?v=_IOZ8_cPgu8
#
# - https://www.geeksforgeeks.org/what-is-computer-networking/?ref=gcse
# - https://www.geeksforgeeks.org/basics-computer-networking/?ref=gcse
# - https://www.geeksforgeeks.org/computer-network-tutorials/?ref=gcse
#
#
# ## Learning Objectives
#
# - Under the basics of computer networking
# - Understand common terms in computer networking
# - Local Area Network (LAN), World Area Network (WAN), Personal Area Network(PAN), Metropolitan Area Network(MAN)
# - Media Access Control(MAC) address
# - Internet Protocol(IP)V4&v6
# - Domain Name System(DNS)
# - Subnetting
# - Tools & Techniques: Ping, Route
# - L2 Switching & L3 Switching
#
# ## What is computer networking
#
# - A computer network is defined as a system that connects two or more computing devices connected by media for transmitting and sharing information
#
# - Computer network consists of: Two or more devices connected by media with apps to support information sharing
#
# - We call the interconnection of computers, a network.
#
# - The Internet is just an interconnection of computers around the world, like a giant spider web that brings all of us together.
#
# - Network protocols are a set of rules for how we transfer data in a network. There are rules that make sure our packets are routed efficiently, aren’t corrupted, are secure, go to the right machine, and are named appropriately.
#
# - The Internet Protocol or IP, is responsible for delivering our packets to the right computers. The Internet Protocol helps us route information.
#
# - The Transmission Control Protocol or TCP, is a protocol that handles reliable delivery of information from one network to another. This protocol was an important part of the creation of the internet since it let us share information with other computers.
#
# ### Building Blocks of networks
# - Devices (Computers, Servers, Printers, Disk Drives etc)
# - Applications (File Transfers, E-mail, Imaging etc)
# - Networks Media (Cables, Routers, Switches etc)
#
#
# ### Common terms in computer networking
#
# - **Internet Protocol(IP) address**: Is a logical address to identify or locate a specific machine/device on a local area network.
#
# - **Switch**: Is a device that sits within the local area network range that helps with the communication among the different nodes on the networrk.
#
# - **A router** is a networking device that forwards data packets between "DIFFERENT" computer computers. A network device that sits between a local area network and the outside network.
#
# - **GATEWAY** - The IP address of the router.
#
# - **Subnet** defines your local area network range.
#
# - **Network Address Translation (NAT)**: is a method of remapping an IP address while they are in transit across a traffic routing device.
#
# - **Firewall**: A set of passive rules to protect the network from unauthorized access to enable a standard communication between the internal and external newtorks.
#
# - **Demilitarized zone (DMZ)**: is a subnetwork that contains and exposes a DEVICE to an untrusted network such as the internet.
#
# - **Port forwarding**: redirects a communication request from one address and port number combination to another while the packets are traversing a network gateway, such as a router or firewall.
#
#
#
# ## IP ADDRESS
#
# **Resources**:
#
# 1. https://www.geeksforgeeks.org/introduction-of-classful-ip-addressing/
#
# ### IP V4
#
# - 192.168.20.3 -> 32 bit binary
# - 4-octets
# - 1 Octet = 8 bits (i.e 10110100)
# - IP address has two parts. Network Ids and Host Ids
# - How to define which section belongs to the network or host part depends on the class of the IP address.
#
# ### IPv4 Classess
#
# - **Class A**: Has range of `1 - 126` and the first part of the octet (8 bits) is dedicated to the network and the rest is dedicated to the host addresses. i.e 2 power 24 (approx. 16 million) host addresses and 126 network addresses. class A is always used for very large organization networks.
#
# - **127.0.0.1** is reserved as loopback (localhost) IP address.
#
# - **Class B**: Hass range of `128 - 191` and the first 2 0ctets (16 bits) are dedicated to the network and the rest is dedicated to the host addresses. Has approx. 16384 ((2 power 16) - 2) network addresses and 65534 host addresses
#
# - **Class C**: has range of `192 - 223` and the first 3 octets (24 bits) are the dedicated to the networkk and the last octect (8 bits) is the host. Has approx. 2 million ((2 power 24) - 3) first 3 bits reserved to identify whether it is class C address) network addresses and 254 ((2 power 8) - 2 Two bits reserved for network IP and broadcast IP) host addresses. This is always used for small organization networks.
#
# - **Class D**: Multicast
#
# - **Class E**: Experimental
#
#
# **Private IP**: IPs used locally only. (i.e 10.0.0.0, 172.6.0.0,192.168.0.0 etc)
#
#
# **Public IP** IP address with the IP range used over public internet.
#
#
# ## Subnetting
#
# ### What is a subnet?
#
# **Resources**:
# 1. https://www.youtube.com/watch?v=qulRjRFavJI
# 2. https://www.geeksforgeeks.org/introduction-of-classful-ip-addressing/
#
# - **Subnet** defines your local area network range.
#
# - **Subnetting** is the practice of dividing a network into two or more networks.
#
# - **A subnet mask** is a 32-bit number created by setting host bits to all 0s and setting network bits to all 1s. In this way, the subnet mask separates the IP.
#
#     - In this way, the subnet mask separates the IP address into the network and host addresses. The `255` address is always assigned to a broadcast address, and the `0` address is always assigned to a network address.
#
#     - **A subnet mask** is defined as a 32-bit address that segregates an IP address into network bits that identify the network and host bits that identify the host device operating on that network.
#
#     - A **class A** network would have a subnet mask of `255.0.0.0` which means that **8 bits** are used for the network. In CIDR notation this is designated by a `/8` following the IP address
#
#     - A **class B** network would have a subnet mask of `255.255.0.0` which means that **16 bits** are used for the network. In CIDR notation this is designated by a `/16` following the IP address
#
#     - A **class C** network would have a subnet mask of `255.255.255.0` which means that **24 bits** are used for the network. In CIDR notation this is designated by a `/24` following the IP address
#
#     - Subnetting is always done from left to right.
#
#     - **CLASSLESS INTER DOMAIN ROUTING (CIDR) or supernetting**: is a method of assigning IP addresses that improves the efficiency of address distribution and replaces the previous system based on `Class A`, `Class B` and `Class C` networks. For more about **CIDR** follow the link [**here**](https://www.techtarget.com/searchnetworking/definition/CIDR#:~:text=CIDR%20(Classless%20Inter%2DDomain%20Routing%20or%20supernetting)%20is%20a,B%20and%20Class%20C%20networks.)
#
#     > **CIDR notation** compactly indicates the network mask for an address and adds on the total number of bits in the entire address using slash notation. For example, `192.168.129.23/17` indicates a `17-bit` network mask. Internet users can refer to a `/17` network to indicate the network's size without specifying an actual network mask.
#
#     - **Network ID**: The portion of an IP address that identifies which `TCP/IP` network the host resides on. For example, if an IP address is `192.158.1.38`., then the network ID is `192.158`. The second half of the address (in this case, 1.38.)
#
#     - **Broadcast ID**: This address is used to transmit data to all of the hosts on the local subnet. The broadcast address is used by multiple protocols such as `ARP`, the `Routing Information Protocol (RIP)`, and other protocols that must transmit data before they know the local subnet mask.
#
#         - An IP broadcast address is the highest number in its class; for example, the broadcast address of a **Class C** `192.168.16.0` network is `192.168.16.255`.
#
#         > **What is the 255.255 255.255 IP address?**
#         > **255.255. 255.255** – Represents the broadcast address, or place to route messages to be sent to every device within a network. **127.0.0.1** – Represents `localhost` or the `loopback address`, allowing a device to refer to itself, regardless of what network it is connected to.
#
#
#
# #### For example taking the class C IP address with the CIDR block `205.150.65.0/26`
#
# - **Subnet mask** will be `255.255.255.192`
#
# - **Network ID address**: Perform a `Logical AND binary operation` of both the address `205.150.65.0` and subnet mask `255.255.255.192`. The result is the **Networrk ID address** of the CIDR block.
#
# <img src="https://w-patri-cil-academy-learning-3624c3d82f8941be9370f9847e70e337.community.saturnenterprise.io/files/examples/examples/tensorflow/images/CIDR_network_ID.png" alt="CIDR Network ID" />
#
# - **Number of subnets**: (2 power n) where n is the number of `of bits given to network in the last octect` and in this case it is `2` and gives **4 subnets**
#
# - **Number of hosts**: ((2 power n) - 2) where n = 6(**number of bits belong to the host**) = (2 power 6) -2  = 62 Hosts
#
# - **Broadcast IP**: Host range is `(205.150.65.1 - 205.150.65.62)`. Therefore the broadcast IP is `205.150.65.63`
#
#
# #### For example taking the class C IP address with the CIDR block `205.150.65.0/24`, create 10 subnets
#
# - To be able to create `10` subnets, this falls in (2 power 4 = 16), which means when `4` network bits from the host bits. Meaning we will only have `4 bits` for the host bits. Therefore the `CIDR` block changes to `205.150.65.0/28`
#
#
# <img src="https://w-patri-cil-academy-learning-3624c3d82f8941be9370f9847e70e337.community.saturnenterprise.io/view/examples/examples/tensorflow/images/cidr_create_subnets.png" alt="CIDR Create subnets" width="200px" />
#
# - **Subnet mask**: 255.255.255.240
#
# - **Network ID address**: 205.150.65.0
#
# - **Number of subnets**: (2 power 4) = 16 subnets
#
# - **Number of hosts**: ((2 power 4) - 2) = 14 hosts
#
# - **Broadcast IP**: Host range is `(205.150.65.1 - 205.150.65.14)`. Therefore the broadcast IP is `205.150.65.15`
#
#
#
#
#
# #### URL
#
# - A **URL**, which stands for **Uniform Resource Locator**, is just a web address similar to a home address.
# - **WWW**: It stands for **World Wide Web**
# - In the `1990`s, a computer scientist by the name of **Tim Berners-Lee** invented the `World Wide Web`
# - **ICANN**, the **Internet Corporation for Assigned Names and Numbers**
#
# - **DNS (Domain Name System)** acts like our Internet’s directory and lets us use human-readable words to map to an IP address. The computer doesn’t know what google.com is. It only knows how to get to an IP address. With DNS, it’s able to map Google’s IP address with google.com. Every time you go on a website, your computer is performing a DNS lookup to find the IP address of the website name you typed in.
#
# - **NAT or Network Address Translation**: This lets organizations use one public IP address and many private IP addresses within the network. Think of NAT as a receptionist at a company.

# %% [markdown]
# ## Individual Project: Answer the following questions
#
# **Resource**: https://www.geeksforgeeks.org/computer-network-tutorials/?ref=gcse
#
# #### 1. What is the IP address of the CIL LMS platform?
#
# -  IP address of `cil.academy` is **52.84.102.70**
#
# #### 2. What are the NS IP addresses of Google, Facebook, and Tesla
#
# - Google (google.com) - NS IP address is **172.217.170.164**
# - Facebook (facebook.com) - NS IP address is **102.132.96.35**
# - Tesla (tesla.com) - NS IP address is **104.89.118.48**
#
# #### 3. What are the main differences between IPV4 and IPV6 addresses?
#
#
# |IPv4	|IPv6|
# |:------|:---|
# |IPv4 has a 32-bit address length	|IPv6 has a 128-bit address length|
# |It Supports Manual and DHCP address configuration	|It supports Auto and renumbering address configuration|
# |In IPv4 end to end, connection integrity is Unachievable	|In IPv6 end to end, connection integrity is Achievable|
# |It can generate 4.29×109 address space	|Address space of IPv6 is quite large it can produce 3.4×1038 address space|
# |The Security feature is dependent on application	|IPSEC is an inbuilt security feature in the IPv6 protocol|
# |Address representation of IPv4 is in decimal	|Address Representation of IPv6 is in hexadecimal|
# |Fragmentation performed by Sender and forwarding routers	|In IPv6 fragmentation performed only by the sender|
# |In IPv4 Packet flow identification is not available	|In IPv6 packet flow identification are Available and uses the flow label field in the header|
# |In IPv4 checksum field is available	|In IPv6 checksum field is not available|
# |It has broadcast Message Transmission Scheme	|In IPv6 multicast and anycast message transmission scheme is available|
# |In IPv4 Encryption and Authentication facility not provided	|In IPv6 Encryption and Authentication are provided|
# |IPv4 has a header of 20-60 bytes.	|IPv6 has header of 40 bytes fixed|
# |IPv4 can be converted to IPv6	|Not all IPv6 can be converted to IPv4|
# |IPv4 consist of 4 fields which are separated by dot (.)	|IPv6 consist of 8 fields, which are separated by colon (:)|
# |IPv4’s  IP addresses are divided into five different classes. Class A , Class B, Class C , Class D , Class E.	|IPv6 does not have any classes of IP address.|
# |IPv4 supports VLSM(Variable Length subnet mask).	|IPv6 does not support VLSM.|
# |Example of IPv4:  66.94.29.13	|Example of IPv6: 2001:0000:3238:DFE1:0063:0000:0000:FEFB|
#
#
# #### 4. Identify the different classes of IPV4 addresses and provide the range of each class(a, b, c, d - m, n, p)?
#
# - **Class A**: Has range of `1 - 126` and the first part of the octet (8 bits) is dedicated to the network and the rest is dedicated to the host addresses. i.e 2 power 24 (approx. 16 million) host addresses and 126 network addresses. class A is always used for very large organization networks.
#
# - **127.0.0.1** is reserved as loopback (localhost) IP address.
#
# - **Class B**: Hass range of `128 - 191` and the first 2 0ctets (16 bits) are dedicated to the network and the rest is dedicated to the host addresses. Has approx. 16384 ((2 power 16) - 2) network addresses and 65534 host addresses
#
# - **Class C**: has range of `192 - 223` and the first 3 octets (24 bits) are the dedicated to the networkk and the last octect (8 bits) is the host. Has approx. 2 million ((2 power 24) - 3) first 3 bits reserved to identify whether it is class C address) network addresses and 254 ((2 power 8) - 2 Two bits reserved for network IP and broadcast IP) host addresses. This is always used for small organization networks.
#
# - **Class D**: Multicast. IP address belonging to class D are reserved for multi-casting. The higher order bits of the first octet of IP addresses belonging to class D are always set to 1110. The remaining bits are for the address that interested hosts recognize.
#
#     Class D does not posses any sub-net mask. IP addresses belonging to class D ranges from 224.0.0.0 – 239.255.255.255.
#
#
# - **Class E**: Experimental. IP addresses belonging to class E are reserved for experimental and research purposes. IP addresses of class E ranges from 240.0.0.0 – 255.255.255.254. This class doesn’t have any sub-net mask. The higher order bits of first octet of class E are always set to 1111.
#
# #### 5. What is MAC address? What is special about the MAC address with this hexadecimal value "FF:FF:FF:FF:FF:FF"?
#
# - **MAC** Addresses are unique 48-bits hardware number of a computer, which is embedded into a network card (known as a **Network Interface Card or NIC**) during the time of manufacturing.
# - **MAC Address** is also known as the **Physical Address** of a network device. In IEEE 802 standard, Data Link Layer is divided into two sublayers –
#
#     - Logical Link Control(LLC) Sublayer
#     - Media Access Control(MAC) Sublayer
# - **MAC** address is used by the `Media Access Control (MAC)` sublayer of the Data-Link Layer. MAC Address is worldwide unique since millions of network devices exist and we need to uniquely identify each.
#
# - Ethernet frames with ones in all bits of the destination address (**FF-FF-FF-FF-FF-FF**) are referred to as the `broadcast addresses`. Frames that are destined with MAC address **FF-FF-FF-FF-FF-FF** will reach every computer belonging to that LAN segment.
#
# #### 6. Provide the actual IPV4 address of the following special IP address types:
#
#    a) Local lookback address - 127.0.0.1
#
#    - Represents “localhost” or the “loopback address”, allowing a device to refer to itself, regardless of what network it is connected to.
#    - The Internet Protocol defines the special network address, 127.0. 0.1, as a local loopback address. Hosts use local loopback addresses to send messages to themselves.
#
#    b) Limited Broadcast address - 255.255.255.255
#
#    - The limited broadcast is used for communication that is limited to the hosts on the local network. These packets always use a destination IPv4 address 255.255. 255.255. Routers do not forward a limited broadcast.
